# %% [markdown]
# <a href="https://colab.research.google.com/github/Ijomriba/Project-/blob/main/Set_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("synthetic_employee_dataset.csv")

# 1. Display the first 10 rows of the dataset
print("First 10 rows of the dataset:")
print(df.head(10))

# 2. Show complete dataset information including data types
print("\nDataset Info:")
print(df.info())

# 3. Determine and display the number of columns and rows
print("\nShape of the dataset:")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# 4. Univariate Analysis

# a) Descriptive statistics for numerical columns
print("\nDescriptive Statistics (Numerical Columns):")
print(df.describe())

# b) Value counts for categorical variables
print("\nValue Counts for Categorical Variables:")
categorical_columns = df.select_dtypes(include='object').columns
for col in categorical_columns:
    print(f"\nColumn: {col}")
    print(df[col].value_counts())

# c) Distribution plots for numerical variables
print("\nPlotting Distribution of Numerical Variables:")
numerical_columns = df.select_dtypes(include='number').columns
for col in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# d) Frequency analysis (value counts) of all columns
print("\nFrequency Analysis of All Columns:")
for col in df.columns:
    print(f"\nColumn: {col}")
    print(df[col].value_counts())
# Out:
# First 10 rows of the dataset:
#    EmployeeID  Age  Gender Department  Salary  YearsOfService  \
# 0           1   37    Male    Finance  110378               4
# 1           2   58    Male  Marketing   86021              26
# 2           3   51    Male    Finance   67179              23
# 3           4   27  Female      Sales   98681              26
# 4           5   43   Other  Marketing   61800              17
# 5           6   51  Female      Sales   70272              19
# 6           7   34  Female    Finance   74962              14
# 7           8   54    Male    Finance   58375              10
# 8           9   36  Female      Sales   63592              25
# 9          10   49  Female      Sales  119851               7
#
#    PerformanceRating
# 0                  4
# 1                  3
# 2                  1
# 3                  3
# 4                  3
# 5                  2
# 6                  3
# 7                  3
# 8                  4
# 9                  3
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         100 non-null    int64
#  1   Age                100 non-null    int64
#  2   Gender             100 non-null    object
#  3   Department         100 non-null    object
#  4   Salary             100 non-null    int64
#  5   YearsOfService     100 non-null    int64
#  6   PerformanceRating  100 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 5.6+ KB
# None
#
# Shape of the dataset:
# Rows: 100, Columns: 7
#
# Descriptive Statistics (Numerical Columns):
#        EmployeeID         Age         Salary  YearsOfService  \
# count  100.000000  100.000000     100.000000      100.000000
# mean    50.500000   40.950000   78716.680000       15.200000
# std     29.011492   11.356816   23687.240526        7.718533
# min      1.000000   22.000000   41910.000000        2.000000
# 25%     25.750000   31.000000   58867.000000        9.000000
# 50%     50.500000   41.500000   76475.500000       15.000000
# 75%     75.250000   51.000000  100707.750000       22.000000
# max    100.000000   59.000000  119851.000000       29.000000
#
#        PerformanceRating
# count         100.000000
# mean            2.950000
# std             0.998737
# min             1.000000
# 25%             2.000000
# 50%             3.000000
# 75%             4.000000
# max             5.000000
#
# Value Counts for Categorical Variables:
#
# Column: Gender
# Gender
# Male      49
# Female    48
# Other      3
# Name: count, dtype: int64
#
# Column: Department
# Department
# Marketing      23
# Engineering    20
# Sales          20
# HR             19
# Finance        18
# Name: count, dtype: int64
#
# Plotting Distribution of Numerical Variables:
# Frequency Analysis of All Columns:
#
# Column: EmployeeID
# EmployeeID
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 96     1
# 97     1
# 98     1
# 99     1
# 100    1
# Name: count, Length: 100, dtype: int64
#
# Column: Age
# Age
# 48    7
# 51    5
# 58    5
# 54    4
# 27    4
# 52    4
# 23    4
# 50    4
# 31    4
# 40    4
# 35    4
# 22    3
# 55    3
# 28    3
# 34    3
# 49    3
# 30    3
# 56    2
# 43    2
# 41    2
# 36    2
# 46    2
# 32    2
# 59    2
# 25    2
# 45    2
# 24    2
# 38    2
# 26    2
# 42    2
# 37    1
# 57    1
# 44    1
# 47    1
# 39    1
# 33    1
# 29    1
# Name: count, dtype: int64
#
# Column: Gender
# Gender
# Male      49
# Female    48
# Other      3
# Name: count, dtype: int64
#
# Column: Department
# Department
# Marketing      23
# Engineering    20
# Sales          20
# HR             19
# Finance        18
# Name: count, dtype: int64
#
# Column: Salary
# Salary
# 110378    1
# 86021     1
# 67179     1
# 98681     1
# 61800     1
#          ..
# 91832     1
# 94502     1
# 43902     1
# 84464     1
# 73114     1
# Name: count, Length: 100, dtype: int64
#
# Column: YearsOfService
# YearsOfService
# 5     8
# 23    7
# 15    6
# 7     5
# 11    5
# 26    5
# 19    5
# 13    4
# 14    4
# 17    4
# 20    4
# 2     4
# 21    3
# 22    3
# 10    3
# 4     3
# 9     3
# 12    3
# 29    3
# 18    3
# 16    3
# 24    3
# 25    2
# 8     2
# 28    2
# 3     2
# 27    1
# Name: count, dtype: int64
#
# Column: PerformanceRating
# PerformanceRating
# 3    43
# 4    25
# 2    18
# 1    10
# 5     4
# Name: count, dtype: int64
